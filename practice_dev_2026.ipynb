# %% [markdown]
# <a href="https://colab.research.google.com/github/niralakumar/practice/blob/main/practice_dev_2026.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# count vowels in a string
# Out:
# 3

# %%
grid = [[4,3,2,-1],[3,2,1,-1],[1,1,-1,-2],[-1,-1,-2,-3]]
def countNegatives(grid):
    rows, cols = len(grid), len(grid[0])
    total_count = 0
    for row in range(rows):
        left, right = 0, cols - 1
        first_true_index = -1

        while left <= right:
            mid = (left + right) // 2
            if grid[row][mid] < 0:
                first_true_index = mid
                right = mid - 1
            else:
                left = mid + 1

        if first_true_index != -1:
            total_count += cols - first_true_index

    return total_count
print(countNegatives(grid))
# Out:
# 8

# %%
grid = [[4,3,2,-1],[3,2,1,-1],[1,1,-1,-2],[-1,-1,-2,-3]]
def countNegatives(grid):
    total_count = 0
    for row in grid:
        for num in row:
            if num < 0:
                total_count += 1
    return total_count
print(countNegatives(grid))
# Out:
# 8

# %%
class Solution:
    def countNegatives(self, grid: List[List[int]]) -> int:
        rows, cols = len(grid), len(grid[0])
        total_count = 0
        for row in range(rows):
            left, right = 0, cols - 1
            first_true_index = -1

            while left <= right:
                mid = (left + right) // 2
                if grid[row][mid] < 0:
                    first_true_index = mid
                    right = mid - 1
                else:
                    left = mid + 1

            if first_true_index != -1:
                total_count += cols - first_true_index
        return total_count

# %%
digits =[1,2,3]
s=''
for i in digits:
    print(i)
    s+=''.join(str(i))
print(s)
st = int(s)
st=st+1
print(st)
stp= str(st)
print(stp)
l=[]
for i in stp:
  print(i)
  l.append(int(i))
print(l)
# Out:
# 1
# 2
# 3
# 123
# 124
# 124
# 1
# 2
# 4
# [1, 2, 4]

# %%
digits =[1,2,3]
s=''
for i in digits:
    s+=''.join(str(i))
st =int(s)+1
stp= str(st)
l=[]
for i in stp:
    l.append(int(i))
print(l)
# Out:
# [1, 2, 4]
